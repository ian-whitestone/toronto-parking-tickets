# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import general_utils as Ugen
import matplotlib.pyplot as plt
import pandas as pd
import math
from pandas.tools.plotting import scatter_matrix
import numpy as np
import glob, os

# %%
##GET DATA
#GET FILES
main_dir=os.getcwd()
allFiles = glob.glob(main_dir.split('/Studies')[0]+'/toronto_parking_data'+ "/*.csv")

#LOAD TO DATAFRAME
list_ = []
for file_path in allFiles[-7:]:#allFiles: #START WITH 2014/2015 DATA
    try:
        df = pd.read_csv(file_path,index_col=None,quoting=2,error_bad_lines=False) #quoting=2
        list_.append(df)
        print ('successfully loaded: '+ file_path)
    except Exception as err:
        if 'EOF following escape character' in str(err):
            try:
                df = pd.read_csv(file_path,index_col=None,encoding='utf-16',error_bad_lines=False) #quoting=2
                list_.append(df)
                print ('successfully loaded: '+ file_path)
            except Exception as err:
                print ('NOT loaded: '+ file_path)
                print (str(err))
        else:
            print ('NOT loaded: '+ file_path)
            print (str(err))
tpt_df = pd.concat(list_)
tpt_df.head()
# Out:
# successfully loaded: /Users/whitesi/Documents/Programming/Python/toronto_parking_data/Parking_Tags_Data_2014_1.csv
# successfully loaded: /Users/whitesi/Documents/Programming/Python/toronto_parking_data/Parking_Tags_Data_2014_2.csv
# successfully loaded: /Users/whitesi/Documents/Programming/Python/toronto_parking_data/Parking_Tags_Data_2014_3.csv
# successfully loaded: /Users/whitesi/Documents/Programming/Python/toronto_parking_data/Parking_Tags_Data_2014_4.csv
# successfully loaded: /Users/whitesi/Documents/Programming/Python/toronto_parking_data/Parking_Tags_Data_2015_1.csv
# successfully loaded: /Users/whitesi/Documents/Programming/Python/toronto_parking_data/Parking_Tags_Data_2015_2.csv
# successfully loaded: /Users/whitesi/Documents/Programming/Python/toronto_parking_data/Parking_Tags_Data_2015_3.csv
#   tag_number_masked  date_of_infraction  infraction_code  \
# 0          ***68436            20140101              134
# 1          ***15940            20140101              192
# 2          ***90323            20140101                9
# 3          ***90324            20140101                8
# 4          ***90325            20140101                8
#
#            infraction_description  set_fine_amount  time_of_infraction  \
# 0             PARK IN PUBLIC LANE               30                   0
# 1       STAND SIGNED TRANSIT STOP               60                   2
# 2  STOP SIGNED HWY PRO TIMES/DAYS               60                   3
# 3   STAND SIGN HWY PRO TIMES/DAYS               60                   5
# 4   STAND SIGN HWY PRO TIMES/DAYS               60                   6
#
#   location1        location2 location3 location4 province
# 0       R/O  157 SELLERS AVE       NaN       NaN       ON
# 1        NR   288 QUEEN ST W       NaN       NaN       ON
# 2        NR   20 COSBURN AVE       NaN       NaN       ON
# 3        NR   30 COSBURN AVE       NaN       NaN       ON
# 4        NR   30 COSBURN AVE       NaN       NaN       ON

# %%
print (tpt_df.shape)
tpt_df.head()
# Out:
# (4653476, 11)
#   tag_number_masked  date_of_infraction  infraction_code  \
# 0          ***68436            20140101              134
# 1          ***15940            20140101              192
# 2          ***90323            20140101                9
# 3          ***90324            20140101                8
# 4          ***90325            20140101                8
#
#            infraction_description  set_fine_amount  time_of_infraction  \
# 0             PARK IN PUBLIC LANE               30                   0
# 1       STAND SIGNED TRANSIT STOP               60                   2
# 2  STOP SIGNED HWY PRO TIMES/DAYS               60                   3
# 3   STAND SIGN HWY PRO TIMES/DAYS               60                   5
# 4   STAND SIGN HWY PRO TIMES/DAYS               60                   6
#
#   location1        location2 location3 location4 province
# 0       R/O  157 SELLERS AVE       NaN       NaN       ON
# 1        NR   288 QUEEN ST W       NaN       NaN       ON
# 2        NR   20 COSBURN AVE       NaN       NaN       ON
# 3        NR   30 COSBURN AVE       NaN       NaN       ON
# 4        NR   30 COSBURN AVE       NaN       NaN       ON

# %%
tpt_df=tpt_df.drop(['tag_number_masked','location3','location4','province'],axis=1)
print (tpt_df.shape)
tpt_df.head()
# Out:
# (4653476, 7)
#    date_of_infraction  infraction_code          infraction_description  \
# 0            20140101              134             PARK IN PUBLIC LANE
# 1            20140101              192       STAND SIGNED TRANSIT STOP
# 2            20140101                9  STOP SIGNED HWY PRO TIMES/DAYS
# 3            20140101                8   STAND SIGN HWY PRO TIMES/DAYS
# 4            20140101                8   STAND SIGN HWY PRO TIMES/DAYS
#
#    set_fine_amount  time_of_infraction location1        location2
# 0               30                   0       R/O  157 SELLERS AVE
# 1               60                   2        NR   288 QUEEN ST W
# 2               60                   3        NR   20 COSBURN AVE
# 3               60                   5        NR   30 COSBURN AVE
# 4               60                   6        NR   30 COSBURN AVE

# %%
tpt_fh_df=tpt_df[tpt_df['infraction_code']==15]
tpt_fh_df.location2.value_counts()

##the following are the top grossing fire hydrants....
##multiply each number by $100 to get total revenue from 2012-2015
# Out:
# 393 UNIVERSITY AVE      795
# 99 ATLANTIC AVE         658
# 33 ELMHURST AVE         590
# 5453 YONGE ST           552
# 361 UNIVERSITY AVE      550
# 592 MARKHAM ST          441
# 500 WELLINGTON ST W     422
# 112 MERTON ST           389
# 56 THE ESPLANADE        387
# 5533 YONGE ST           376
# 5460 YONGE ST           373
# 17 LILLIAN ST           331
# DORIS AVE               314
# 5100 YONGE ST           300
# 6 SPRING GARDEN AVE     287
# 17 NIAGARA ST           269
# 21 GLEBE RD E           268
# 150 KILGOUR RD          258
# 295 RONCESVALLES AVE    255
# 123 SUNNYSIDE AVE       252
# 90 KIPPENDAVIE AVE      243
# 293 RONCESVALLES AVE    234
# 387 QUEEN ST W          233
# 26 WELLINGTON ST E      229
# 4965 YONGE ST           222
# 139 WOODWARD AVE        221
# 49 BELLEVUE AVE         219
# 5645 YONGE ST           218
# 4900 YONGE ST           211
# 43 ELM ST               200
#                        ...
# 318 CLINTON ST            1
# 280 SHUTER ST             1
# 11 THOROUGHBRED CRES      1
# 245 WOODFIELD RD          1
# 386 SPADINA RD            1
# 255 LANSDOWNE AVE         1
# 26 NORTON AVE             1
# 59 BERNARD AVE            1
# 328 SORAUREN AVE          1
# 159 BLEECKER ST           1
# AERODROME CRES            1
# 89 ESSEX ST               1
# 41 HOWIE AVE              1
# 140 HANNA AVE             1
# 619 BERESFORD AVE         1
# 32 LAUDER AVE             1
# 941 LOGAN AVE             1
# 30 ALMORE AVE             1
# 1012 ST CLARENS AVE       1
# 8494 YONGE ST             1
# 58 PHOEBE ST              1
# 365 FRONT ST W            1
# HOVE ST                   1
# 2 WELLINGTON ST E         1
# 339 CHURCH ST             1
# 64 MARJORY AVE            1
# 479 WELLINGTON ST W       1
# 173 RONCESVALLES AVE      1
# 126 HILTON AVE            1
# 50 GLEN STEWART AVE       1
# Name: location2, dtype: int64

# %%
##LETS FIND THE HIGHEST GROSSING PERIOD
infraction_ids=list(tpt_df.infraction_code.unique())

# tpt_df.groupby(['infraction_code','location2']).size()
#tpt_df.groupby(['infraction_code','location2']).location2.count()

tpt_df_mod=tpt_df.iloc[:500000]
tpt_df_mod=tpt_df_mod.sort_values('location2')

# tpt_df_mod['counts']=tpt_df_mod.groupby(['infraction_code','location2']).location2.transform('count')
# tpt_df_mod

# %%
tpt_df_mod.shape
# sorted_df.columns.values
# Out:
# (500000, 7)

# %%
#DROP MISSING LOCATIONS
tpt_df_mod=tpt_df_mod[pd.notnull(tpt_df_mod['location2'])]
tpt_df_mod.shape
# Out:
# (499919, 7)

# %%
new_df=pd.DataFrame({'count' : tpt_df_mod.groupby( ['infraction_code','location2'] ).size()}).reset_index()
print(new_df.shape)
# Out:
# (142065, 3)

# %%
##now calculate total amount...
##create dict of infraction_code:fine_amount
fine_amount_dict={ic:{'fine_amt':tpt_df[tpt_df['infraction_code']==ic].set_fine_amount.median(),
                      'fine_descp':tpt_df[tpt_df['infraction_code']==ic].infraction_description.iloc[0]}    
                          for ic in infraction_ids}


def calc_fine_sum(df):
    return df['count']*fine_amount_dict[df['infraction_code']]['fine_amt']

def get_fine_descrp(df):
    return fine_amount_dict[df['infraction_code']]['fine_descp']

new_df['fine_sum']=new_df.apply(calc_fine_sum,axis=1)
new_df['fine_descrp']=new_df.apply(get_fine_descrp,axis=1)

# %%
new_df.sort_values('fine_sum',ascending=False)
# Out:
#         infraction_code              location2  count  fine_sum  \
# 121909              347     939 LAWRENCE AVE E    200     50000
# 120987              347      1090 DON MILLS RD    150     37500
# 122664              367        18 GRENVILLE ST     83     37350
# 122702              367         410 COLLEGE ST     83     37350
# 122484              363          35 BALMUTO ST     79     35550
# 24027                 5           20 EDWARD ST    877     35080
# 13873                 3       2075 BAYVIEW AVE   1043     31290
# 121630              347        45 OVERLEA BLVD    117     29250
# 44179                 8      20 EGLINTON AVE W    430     25800
# 12670                 3      1265 MILITARY TRL    836     25080
# 122785              369           60 MURRAY ST     51     22950
# 17805                 3       941 PROGRESS AVE    745     22350
# 122219              355       555 REXDALE BLVD     45     20250
# 121441              347         300 BOROUGH DR     80     20000
# 48282                 9         25 LEONARD AVE    303     18180
# 45038                 8   40 ORCHARD VIEW BLVD    290     17400
# 98311               134          60 BLOOR ST W    435     17400
# 50039                 9        60 GROSVENOR ST    284     17040
# 44200                 8          200 KING ST E    283     16980
# 45036                 8           40 MURRAY ST    276     16560
# 121871              347        85 ELLESMERE RD     64     16000
# 13302                 3       1750 FINCH AVE E    517     15510
# 27208                 5    30 GRAND TRUNK CRES    378     15120
# 25583                 5          2401 YONGE ST    372     14880
# 13092                 3        155 LEGION RD N    472     14160
# 17171                 3      700 LAWRENCE AV W    468     14040
# 123694              401             18 ORDE ST     91     13650
# 12151                 3       1000 FINCH AVE W    444     13320
# 122878              374       130 ELIZABETH ST     44     13200
# 54274                15     393 UNIVERSITY AVE    132     13200
# ...                 ...                    ...    ...       ...
# 3628                  2          2 HARDISTY DR      1        15
# 3627                  2         2 GRANTOWN AVE      1        15
# 3625                  2          2 GOSFIELD GT      1        15
# 3562                  2         198 LINDEN AVE      1        15
# 3624                  2         2 GOLFHAVEN DR      1        15
# 57350                26         96 YORKVIEW DR      1         0
# 43385                 7       31 TOPSCOTT ROAD      1         0
# 57289                24      45 ST CLAIR AVE W      1         0
# 43388                 7       5230 DUNDAS ST W      1         0
# 98608               148        100 S GEORGE ST      1         0
# 98610               148        75 ST GEORGE ST      1         0
# 95303                33      396 HUILLMOUNT AV      1         0
# 51372                10     20 EPPLEWORTH ROAD      1         0
# 51373                10     2257 ISLINGTON AVE      2         0
# 51374                10         2625 WESTON RD      1         0
# 51375                10      8 GLEN WATFORD DR      1         0
# 51376                10   8 GLEN WATFORD DRIVE      1         0
# 43389                 7               YORK AVE      1         0
# 43387                 7         500 REXDALE BL      1         0
# 43379                 7           22 TUXEDO CT      1         0
# 43386                 7  34 DIXINGTON CRESCENT      1         0
# 43384                 7    30 HUMBERLINE DRIVE      1         0
# 43383                 7       2777 KIPLING AVE      1         0
# 57286                24            1 IRWIN AVE      1         0
# 43382                 7         250 WINCOTT DR      1         0
# 43381                 7    2428 EGLINTON AVE E      1         0
# 57287                24            1170 BAY ST      1         0
# 57288                24      234 PARLIAMENT ST      1         0
# 43380                 7          234 ALBION RD      1         0
# 98609               148        50 ST GEORGE ST      1         0
#
#                            fine_descrp
# 121909            PARK IN A FIRE ROUTE
# 120987            PARK IN A FIRE ROUTE
# 122664  STND ONSTRT ACCESSIBLE NO PRMT
# 122702  STND ONSTRT ACCESSIBLE NO PRMT
# 122484  PARK ONSTRT ACCESSIBLE NO PRMT
# 24027       PARK HWY PROHIBED TIME/DAY
# 13873   PARK/LEAVE ON PRIVATE PROPERTY
# 121630            PARK IN A FIRE ROUTE
# 44179    STAND SIGN HWY PRO TIMES/DAYS
# 12670   PARK/LEAVE ON PRIVATE PROPERTY
# 122785  STND ONSTRT ACCESSIBLE NOT D/O
# 17805   PARK/LEAVE ON PRIVATE PROPERTY
# 122219    PARK IN ACCESSIBLE NO PERMIT
# 121441            PARK IN A FIRE ROUTE
# 48282   STOP SIGNED HWY PRO TIMES/DAYS
# 45038    STAND SIGN HWY PRO TIMES/DAYS
# 98311              PARK IN PUBLIC LANE
# 50039   STOP SIGNED HWY PRO TIMES/DAYS
# 44200    STAND SIGN HWY PRO TIMES/DAYS
# 45036    STAND SIGN HWY PRO TIMES/DAYS
# 121871            PARK IN A FIRE ROUTE
# 13302   PARK/LEAVE ON PRIVATE PROPERTY
# 27208       PARK HWY PROHIBED TIME/DAY
# 25583       PARK HWY PROHIBED TIME/DAY
# 13092   PARK/LEAVE ON PRIVATE PROPERTY
# 17171   PARK/LEAVE ON PRIVATE PROPERTY
# 123694       PARK-SIGNED HWY-RUSH HOUR
# 12151   PARK/LEAVE ON PRIVATE PROPERTY
# 122878       STAND BUS PROHIBITED TIME
# 54274       PARK - 3 M OF FIRE HYDRANT
# ...                                ...
# 3628          PARK-LONGER THAN 3 HOURS
# 3627          PARK-LONGER THAN 3 HOURS
# 3625          PARK-LONGER THAN 3 HOURS
# 3562          PARK-LONGER THAN 3 HOURS
# 3624          PARK-LONGER THAN 3 HOURS
# 57350              PARK - ON BOULEVARD
# 43385    PARK IN DESIGNATED FIRE ROUTE
# 57289    PARK TAXI-FOR HR-UNATH LOCATN
# 43388    PARK IN DESIGNATED FIRE ROUTE
# 98608   STOP/STAND/PARK VEND CONT ZONE
# 98610   STOP/STAND/PARK VEND CONT ZONE
# 95303   STAND VEHICLE-SIGNED HIGHWAY-3
# 51372   PARK UNAUTH VEH IN HDCPD SPACE
# 51373   PARK UNAUTH VEH IN HDCPD SPACE
# 51374   PARK UNAUTH VEH IN HDCPD SPACE
# 51375   PARK UNAUTH VEH IN HDCPD SPACE
# 51376   PARK UNAUTH VEH IN HDCPD SPACE
# 43389    PARK IN DESIGNATED FIRE ROUTE
# 43387    PARK IN DESIGNATED FIRE ROUTE
# 43379    PARK IN DESIGNATED FIRE ROUTE
# 43386    PARK IN DESIGNATED FIRE ROUTE
# 43384    PARK IN DESIGNATED FIRE ROUTE
# 43383    PARK IN DESIGNATED FIRE ROUTE
# 57286    PARK TAXI-FOR HR-UNATH LOCATN
# 43382    PARK IN DESIGNATED FIRE ROUTE
# 43381    PARK IN DESIGNATED FIRE ROUTE
# 57287    PARK TAXI-FOR HR-UNATH LOCATN
# 57288    PARK TAXI-FOR HR-UNATH LOCATN
# 43380    PARK IN DESIGNATED FIRE ROUTE
# 98609   STOP/STAND/PARK VEND CONT ZONE
#
# [142065 rows x 5 columns]

# %%
new_df[new_df['location2']=='939 LAWRENCE AVE E']
# Out:
#         infraction_code           location2  count  fine_sum  \
# 17797                 3  939 LAWRENCE AVE E     28       840
# 121909              347  939 LAWRENCE AVE E    200     50000
# 122303              355  939 LAWRENCE AVE E     15      6750
# 122342              357  939 LAWRENCE AVE E      2       900
#
#                            fine_descrp
# 17797   PARK/LEAVE ON PRIVATE PROPERTY
# 121909            PARK IN A FIRE ROUTE
# 122303    PARK IN ACCESSIBLE NO PERMIT
# 122342    PARK ACCESSIBLE NOT DROP OFF

# %%
tpt_df.columns
# Out:
# Index(['date_of_infraction', 'infraction_code', 'infraction_description',
#        'set_fine_amount', 'time_of_infraction', 'location1', 'location2'],
#       dtype='object')

# %%
##get unique values of infraction times

tpt_df.time_of_infraction.mean()
# Out:
# 1184.5459498081186

# %%
import requests

url_pt1="https://maps.googleapis.com/maps/api/geocode/json?address="

def get_coords(df):
    street=df['location2']
    try:
        response = requests.get(url_pt1+df['location2'].replace(' ','+')+',+Toronto,+ON,+Canada')
        resp_json_payload = response.json()
        coords=resp_json_payload['results'][0]['geometry']['location']
        if ('lng' and 'lat') in list(coords.keys()):
            return coords
    except:
        pass
    return

new2_df=new_df.iloc[:100]
new2_df['coords']=new2_df.apply(get_coords,axis=1)
